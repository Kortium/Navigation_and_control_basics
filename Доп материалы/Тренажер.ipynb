# %% [markdown]
# ## Основы Jupyter и Python

# %% [markdown]
# Импортируйте библиотеки
#
# **math**
# **ipywidgets** под именем **widgets**
# модуль **pyplot** из библиотеки **matplotlib** под именем **plt**

# %% [markdown]
# Создать список "a" размера 10 заполненный числами от 0 до 9

# %% [markdown]
# Создать список "b" размера 10 заполненный числами от 10 до 1

# %% [markdown]
# Объединить списки "a" и "b" в один список

# %% [markdown]
# Получить список состоящий 10 единичек

# %% [markdown]
# Вывести длину списка "а"

# %% [markdown]
# Вывести список "a" умноженный на 2

# %% [markdown]
# Вывести матричное произведение списков "a" и "b", рассматривая "a" как вектор столбец, а "b" как вектор строку

# %% [markdown]
# Задать массив X от 0 до 10 с шагом 0.01

# %% [markdown]
# Задать массив Y = sin(X)

# %% [markdown]
# Построить график Y(X)

# %% [markdown]
# Задайте функцию которая будет расчитывать дискрименант квадратного уравнения вида
#
# \begin{align}
# ax^2+bx+c=0
# \end{align}
#
# В качестве входных параметров подаются параметры a,b и c

# %% [markdown]
# Создайте интерактивный элемент для переменной A

# %% [markdown]
# Постройте график функции
#
# \begin{align}
# y = Asin(wx)
# \end{align}
#
# С интерактивно настраиваемыми параметрами A и w

# %% [markdown]
# Модифицируйте функцию таким образом что бы она постепенно приближалась к 0

# %% [markdown]
# Запишите формулу получившейся функции используя markdown

# %% [markdown]
# Ознакомьтесь с методом построения таблиц с помощью markdown. Задайте свою таблицу в следующей за этой ячейке.

# %% [markdown]
# Добавьте в начало ячейку со списком исполнителей.
